# %% [markdown]
# ## 1. Fetching the data

# %%
import sys
sys.path.insert(0, '..')  # points to fpl-engine/ from notebooks/

from fpl_engine.api_client import (fetch_bootstrap, fetch_fixtures, fetch_all_player_histories)

bootstrap = fetch_bootstrap()
fixtures = fetch_fixtures()
# Out:
# Loaded 841 players
# Loaded 20 teams
# Loaded 380 fixtures

# %%
# Player data

player_ids = [p['id'] for p in bootstrap['elements']]
print(f"Total players: {len(player_ids)}")

fetch_all_player_histories(player_ids)
# Out:
# Total players: 841
#  0/841 players fetched...
#  50/841 players fetched...
#  100/841 players fetched...
#  150/841 players fetched...
#  200/841 players fetched...
#  250/841 players fetched...
#  300/841 players fetched...
#  350/841 players fetched...
#  400/841 players fetched...
#  450/841 players fetched...
#  500/841 players fetched...
#  550/841 players fetched...
#  600/841 players fetched...
#  650/841 players fetched...
#  700/841 players fetched...
#  750/841 players fetched...
#  800/841 players fetched...
# Done - all player histories saved
