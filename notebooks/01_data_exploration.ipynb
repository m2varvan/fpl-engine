# %%
import sys
sys.path.insert(0, '..')  # points to fpl-engine/ from notebooks/

from fpl_engine.api_client import (fetch_bootstrap, fetch_fixtures, fetch_all_player_histories)

bootstrap = fetch_bootstrap()
fixtures = fetch_fixtures()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 import sys
#       2 sys.path.insert(0, '..')  # points to fpl-engine/ from notebooks/
#       3
# ----> 4 from fpl_engine.api_client import (fetch_bootstrap, fetch_fixtures, fetch_all_player_histories)
#       5
#       6 bootstrap = fetch_bootstrap()
#       7 fixtures = fetch_fixtures()
#
# ImportError: cannot import name 'fetch_bootstrap' from 'fpl_engine.api_client' (/Users/muhammadvarvani/Desktop/Personal_Projects/fpl-engine/notebooks/../fpl_engine/api_client.py)

# %% [markdown]
# ## Hello World
